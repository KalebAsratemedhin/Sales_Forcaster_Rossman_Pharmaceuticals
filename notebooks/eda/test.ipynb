# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../src')))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../scripts')))

# %%
from utils import *
from plots import *

# %% [markdown]
# # EDA

# %%
df = data_loader('../../data/test.csv')

# %%
df.shape
# Out:
# (41088, 8)

# %%
df.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
df.describe()
# Out:
#                  Id         Store     DayOfWeek          Open         Promo  \
# count  41088.000000  41088.000000  41088.000000  41077.000000  41088.000000
# mean   20544.500000    555.899533      3.979167      0.854322      0.395833
# std    11861.228267    320.274496      2.015481      0.352787      0.489035
# min        1.000000      1.000000      1.000000      0.000000      0.000000
# 25%    10272.750000    279.750000      2.000000      1.000000      0.000000
# 50%    20544.500000    553.500000      4.000000      1.000000      0.000000
# 75%    30816.250000    832.250000      6.000000      1.000000      1.000000
# max    41088.000000   1115.000000      7.000000      1.000000      1.000000
#
#        SchoolHoliday
# count   41088.000000
# mean        0.443487
# std         0.496802
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %% [markdown]
# # Summary

# %%
summary_df = column_summary(df)
display(summary_df)
# Out:
#         col_name col_dtype  num_of_nulls  num_of_non_nulls  \
# 0             Id     int64             0             41088
# 1          Store     int64             0             41088
# 2      DayOfWeek     int64             0             41088
# 3           Date    object             0             41088
# 4           Open   float64            11             41077
# 5          Promo     int64             0             41088
# 6   StateHoliday    object             0             41088
# 7  SchoolHoliday     int64             0             41088
#
#    num_of_distinct_values                             distinct_values_counts
# 0                   41088  {41072: 1, 41071: 1, 41070: 1, 41069: 1, 41068...
# 1                     856  {1115: 48, 1: 48, 3: 48, 7: 48, 8: 48, 9: 48, ...
# 2                       7  {4: 5992, 3: 5992, 2: 5992, 1: 5992, 7: 5992, ...
# 3                      48  {'2015-09-17': 856, '2015-09-16': 856, '2015-0...
# 4                       2                            {1.0: 35093, 0.0: 5984}
# 5                       2                               {0: 24824, 1: 16264}
# 6                       2                             {'0': 40908, 'a': 180}
# 7                       2                               {0: 22866, 1: 18222}

# %% [markdown]
# # Missing Values

# %%
impute_missing_values(df, 'Open', 'mode')
# Out:
# /home/kaleb/projects/kaim/Sales_Forcaster_Rossman_Pharmaceuticals/scripts/utils.py:81: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(value, inplace=True)
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 0          1      1          4  2015-09-17   1.0      1            0
# 1          2      3          4  2015-09-17   1.0      1            0
# 2          3      7          4  2015-09-17   1.0      1            0
# 3          4      8          4  2015-09-17   1.0      1            0
# 4          5      9          4  2015-09-17   1.0      1            0
# ...      ...    ...        ...         ...   ...    ...          ...
# 41083  41084   1111          6  2015-08-01   1.0      0            0
# 41084  41085   1112          6  2015-08-01   1.0      0            0
# 41085  41086   1113          6  2015-08-01   1.0      0            0
# 41086  41087   1114          6  2015-08-01   1.0      0            0
# 41087  41088   1115          6  2015-08-01   1.0      0            0
#
#        SchoolHoliday
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 41083              0
# 41084              0
# 41085              0
# 41086              0
# 41087              1
#
# [41088 rows x 8 columns]

# %% [markdown]
# # Save Cleaned Data

# %%
save_dataframe_to_csv(df, 'cleaned_test_data.csv')

# %%
univariate_analysis(df, 'Store')

# %%
univariate_analysis(df, 'Promo')
